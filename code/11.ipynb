# %%
'''
Task: redirect the URL to new page ID
Ressources: mention_url.csv
            wiki_id_qid.csv
Outputs: mentions_url_including_redirect.csv, all mention URLs including the redirect URLs
'''
import wikipedia
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
import time
import requests
import os

# Set the language for Wikipedia queries
wikipedia.set_lang('de')
wikipedia.set_rate_limiting(True)

current_directory = os.getcwd().replace('code', '')
data_path = os.path.join(current_directory, 'data')
output_path = os.path.join(current_directory, 'outputs')
# Function to fetch Wikipedia page ids
def get_page_id(title):
    try:
        page = wikipedia.page(title=title, redirect=True, auto_suggest=False)
        return page.pageid
    except:
        return None

df_mention_url = pd.read_csv(os.path.join(output_path, 'mention_url.csv'))
df_mention = pd.read_csv(os.path.join(output_path, 'mention.csv'))
merged_df = pd.merge(df_mention, df_mention_url, on='url', how='left')
df_qid = pd.read_csv(os.path.join(output_path, 'wiki_id_qid.csv'))
merged_df1 = pd.merge(merged_df, df_qid, on='page id', how='left')

# %%
merged_df_na = merged_df1[merged_df1['qid'].isna()]
titles = list(set(merged_df_na['mention']))

# %%
titles = list(set(merged_df_na['mention']))
len(titles)
# Out:
# 122498

# %%
# Concurrently fetch page ids using multi-threading
with ThreadPoolExecutor() as executor:
    results = list(tqdm(executor.map(get_page_id, titles), total=len(titles)))

rows = []
for i, j in zip(titles, results):
    rows.append([i, j])
    
df = pd.DataFrame(rows, columns=['mention', 'new page id'])
merged_df = pd.merge(merged_df_na, df, on='mention', how='left')

# %%
urls = list(merged_df['url'])
len(urls)
# Out:
# 127037

# %%
def check_url_existence(url):
    time.sleep(1)
    try:
        response = requests.head(url)
        if response.status_code == 200:  # 200 indicates a successful request
            return 200
        else:
            if response.status_code == 429:
                print(f"Error occurred while fetching {url}: Status Code {429}")
            return response.status_code 
    except requests.RequestException:
        return None
urls = list(merged_df1['url'])  
with ThreadPoolExecutor() as executor:
    error = list(tqdm(executor.map(check_url_existence, urls), total=len(urls)))
# Out:
# 100%|██████████| 127037/127037 [2:42:41<00:00, 13.01it/s]

# %%
merged_df['new error']=error

# %%
merged_df
# Out:
#                        mention  \
# 0              Aluminiumgehalt
# 1                    hydrophil
# 2                           EU
# 3          4-"n"-Nonylphenolen
# 4                     östrogen
# ...                        ...
# 127032                Dalvirus
# 127033                Deevirus
# 127034              Dobrovirus
# 127035           Thurisazvirus
# 127036  biologischen Evolution
#
#                                                       url     page id  error  \
# 0           https://de.wikipedia.org/wiki/Aluminiumgehalt         0.0  200.0
# 1                 https://de.wikipedia.org/wiki/hydrophil     76478.0  200.0
# 2                        https://de.wikipedia.org/wiki/EU    949615.0  200.0
# 3           https://de.wikipedia.org/wiki/4-n-Nonylphenol  12381567.0  200.0
# 4             https://de.wikipedia.org/wiki/%C3%B6strogen  11875637.0  200.0
# ...                                                   ...         ...    ...
# 127032             https://de.wikipedia.org/wiki/Dalvirus         0.0  200.0
# 127033             https://de.wikipedia.org/wiki/Deevirus         0.0  200.0
# 127034           https://de.wikipedia.org/wiki/Dobrovirus         0.0  200.0
# 127035        https://de.wikipedia.org/wiki/Thurisazvirus         0.0  200.0
# 127036  https://de.wikipedia.org/wiki/biologische%20Ev...   1857222.0  200.0
#
#         qid new page id  new error
# 0       NaN        None        404
# 1       NaN        2256        301
# 2       NaN        7604        200
# 3       NaN        None        200
# 4       NaN       11633        200
# ...     ...         ...        ...
# 127032  NaN        None        404
# 127033  NaN        None        404
# 127034  NaN        None        404
# 127035  NaN        None        404
# 127036  NaN        None        301
#
# [127037 rows x 7 columns]

# %%
merged_df.to_csv(os.path.join(output_path, 'mentions_redirect_qid.csv'), index=False)

# %%
rows = []
for num, val in enumerate(tqdm(merged_df['new error'])):
    if int(val) == 200 or int(val) == 301:
        if merged_df['new page id'][num] != None:
            rows.append(merged_df['new page id'][num])
        else:
            rows.append(merged_df['page id'][num])
    else:
        rows.append(merged_df['page id'][num])
# Out:
# 100%|██████████| 127037/127037 [00:01<00:00, 114083.89it/s]

# %%
merged_df['new page id 1']=rows
merged_df
# Out:
#                        mention  \
# 0              Aluminiumgehalt
# 1                    hydrophil
# 2                           EU
# 3          4-"n"-Nonylphenolen
# 4                     östrogen
# ...                        ...
# 127032                Dalvirus
# 127033                Deevirus
# 127034              Dobrovirus
# 127035           Thurisazvirus
# 127036  biologischen Evolution
#
#                                                       url     page id  error  \
# 0           https://de.wikipedia.org/wiki/Aluminiumgehalt         0.0  200.0
# 1                 https://de.wikipedia.org/wiki/hydrophil     76478.0  200.0
# 2                        https://de.wikipedia.org/wiki/EU    949615.0  200.0
# 3           https://de.wikipedia.org/wiki/4-n-Nonylphenol  12381567.0  200.0
# 4             https://de.wikipedia.org/wiki/%C3%B6strogen  11875637.0  200.0
# ...                                                   ...         ...    ...
# 127032             https://de.wikipedia.org/wiki/Dalvirus         0.0  200.0
# 127033             https://de.wikipedia.org/wiki/Deevirus         0.0  200.0
# 127034           https://de.wikipedia.org/wiki/Dobrovirus         0.0  200.0
# 127035        https://de.wikipedia.org/wiki/Thurisazvirus         0.0  200.0
# 127036  https://de.wikipedia.org/wiki/biologische%20Ev...   1857222.0  200.0
#
#         qid new page id  new error new page id 1
# 0       NaN        None        404           0.0
# 1       NaN        2256        301          2256
# 2       NaN        7604        200          7604
# 3       NaN        None        200    12381567.0
# 4       NaN       11633        200         11633
# ...     ...         ...        ...           ...
# 127032  NaN        None        404           0.0
# 127033  NaN        None        404           0.0
# 127034  NaN        None        404           0.0
# 127035  NaN        None        404           0.0
# 127036  NaN        None        301     1857222.0
#
# [127037 rows x 8 columns]

# %%
merged_df.to_csv(os.path.join(output_path, 'mentions_redirect_qid.csv'), index=False)

# %%
rows = []
for num, val in enumerate(tqdm(merged_df['new error'])):
    try:
        page_id = int(merged_df['new page id 1'][num])
    except:
        page_id = merged_df['new page id 1'][num]
    rows.append([merged_df['mention'][num], merged_df['url'][num], page_id, merged_df['new error'][num]])
# Out:
# 100%|██████████| 127037/127037 [00:04<00:00, 30418.09it/s]

# %%
df_re = pd.DataFrame(rows, columns=['mention', 'url', 'page id', 'error'])
df_re
# Out:
#                        mention  \
# 0              Aluminiumgehalt
# 1                    hydrophil
# 2                           EU
# 3          4-"n"-Nonylphenolen
# 4                     östrogen
# ...                        ...
# 127032                Dalvirus
# 127033                Deevirus
# 127034              Dobrovirus
# 127035           Thurisazvirus
# 127036  biologischen Evolution
#
#                                                       url     page id  error
# 0           https://de.wikipedia.org/wiki/Aluminiumgehalt         0.0    404
# 1                 https://de.wikipedia.org/wiki/hydrophil      2256.0    301
# 2                        https://de.wikipedia.org/wiki/EU      7604.0    200
# 3           https://de.wikipedia.org/wiki/4-n-Nonylphenol  12381567.0    200
# 4             https://de.wikipedia.org/wiki/%C3%B6strogen     11633.0    200
# ...                                                   ...         ...    ...
# 127032             https://de.wikipedia.org/wiki/Dalvirus         0.0    404
# 127033             https://de.wikipedia.org/wiki/Deevirus         0.0    404
# 127034           https://de.wikipedia.org/wiki/Dobrovirus         0.0    404
# 127035        https://de.wikipedia.org/wiki/Thurisazvirus         0.0    404
# 127036  https://de.wikipedia.org/wiki/biologische%20Ev...   1857222.0    301
#
# [127037 rows x 4 columns]

# %%
merged_df_qid = pd.merge(df_re, df_qid, on='page id', how='left')
merged_df_qid
# Out:
#                        mention  \
# 0              Aluminiumgehalt
# 1                    hydrophil
# 2                           EU
# 3          4-"n"-Nonylphenolen
# 4                     östrogen
# ...                        ...
# 127032                Dalvirus
# 127033                Deevirus
# 127034              Dobrovirus
# 127035           Thurisazvirus
# 127036  biologischen Evolution
#
#                                                       url     page id  error  \
# 0           https://de.wikipedia.org/wiki/Aluminiumgehalt         0.0    404
# 1                 https://de.wikipedia.org/wiki/hydrophil      2256.0    301
# 2                        https://de.wikipedia.org/wiki/EU      7604.0    200
# 3           https://de.wikipedia.org/wiki/4-n-Nonylphenol  12381567.0    200
# 4             https://de.wikipedia.org/wiki/%C3%B6strogen     11633.0    200
# ...                                                   ...         ...    ...
# 127032             https://de.wikipedia.org/wiki/Dalvirus         0.0    404
# 127033             https://de.wikipedia.org/wiki/Deevirus         0.0    404
# 127034           https://de.wikipedia.org/wiki/Dobrovirus         0.0    404
# 127035        https://de.wikipedia.org/wiki/Thurisazvirus         0.0    404
# 127036  https://de.wikipedia.org/wiki/biologische%20Ev...   1857222.0    301
#
#               qid
# 0             NaN
# 1       Q41853520
# 2            Q458
# 3             NaN
# 4         Q277954
# ...           ...
# 127032        NaN
# 127033        NaN
# 127034        NaN
# 127035        NaN
# 127036        NaN
#
# [127037 rows x 5 columns]

# %%
merged_df_nna = merged_df1[merged_df1['qid'].notna()]
merged_df_nna
# Out:
#                     mention  \
# 0                  Getreide
# 1                   Gattung
# 2              Fingerhirsen
# 3                   Familie
# 4                 Süßgräser
# ...                     ...
# 468358          Hyperzyklus
# 468359         Quasispezies
# 468360                 Java
# 468361  Spreitenquerschnitt
# 468362               Ko Yao
#
#                                                       url    page id  error  \
# 0                  https://de.wikipedia.org/wiki/Getreide     1944.0  200.0
# 1       https://de.wikipedia.org/wiki/Gattung%20%28Bio...  4003287.0  200.0
# 2              https://de.wikipedia.org/wiki/Fingerhirsen  3719543.0  200.0
# 3       https://de.wikipedia.org/wiki/Familie%20%28Bio...     1704.0  200.0
# 4       https://de.wikipedia.org/wiki/S%C3%BC%C3%9Fgr%...     4951.0  200.0
# ...                                                   ...        ...    ...
# 468358          https://de.wikipedia.org/wiki/Hyperzyklus   585746.0  200.0
# 468359         https://de.wikipedia.org/wiki/Quasispezies  1011909.0  200.0
# 468360                 https://de.wikipedia.org/wiki/Java     2521.0  200.0
# 468361  https://de.wikipedia.org/wiki/Blattform%23Spre...  1528179.0  200.0
# 468362    https://de.wikipedia.org/wiki/Amphoe%20Ko%20Yao  3451158.0  200.0
#
#              qid
# 0         Q12117
# 1         Q34740
# 2        Q163915
# 3         Q35409
# 4         Q43238
# ...          ...
# 468358  Q4138754
# 468359   Q456225
# 468360  Q1100132
# 468361   Q521246
# 468362   Q475812
#
# [341326 rows x 5 columns]

# %%
concatenated_df = pd.concat([merged_df_nna, merged_df_qid], ignore_index=True)
concatenated_df.to_csv(os.path.join(output_path, 'mentions_url_including_redirect.csv'), index=False)

# %%
concatenated_df
# Out:
#                        mention  \
# 0                     Getreide
# 1                      Gattung
# 2                 Fingerhirsen
# 3                      Familie
# 4                    Süßgräser
# ...                        ...
# 468358                Dalvirus
# 468359                Deevirus
# 468360              Dobrovirus
# 468361           Thurisazvirus
# 468362  biologischen Evolution
#
#                                                       url    page id  error  \
# 0                  https://de.wikipedia.org/wiki/Getreide     1944.0  200.0
# 1       https://de.wikipedia.org/wiki/Gattung%20%28Bio...  4003287.0  200.0
# 2              https://de.wikipedia.org/wiki/Fingerhirsen  3719543.0  200.0
# 3       https://de.wikipedia.org/wiki/Familie%20%28Bio...     1704.0  200.0
# 4       https://de.wikipedia.org/wiki/S%C3%BC%C3%9Fgr%...     4951.0  200.0
# ...                                                   ...        ...    ...
# 468358             https://de.wikipedia.org/wiki/Dalvirus        0.0  404.0
# 468359             https://de.wikipedia.org/wiki/Deevirus        0.0  404.0
# 468360           https://de.wikipedia.org/wiki/Dobrovirus        0.0  404.0
# 468361        https://de.wikipedia.org/wiki/Thurisazvirus        0.0  404.0
# 468362  https://de.wikipedia.org/wiki/biologische%20Ev...  1857222.0  301.0
#
#             qid
# 0        Q12117
# 1        Q34740
# 2       Q163915
# 3        Q35409
# 4        Q43238
# ...         ...
# 468358      NaN
# 468359      NaN
# 468360      NaN
# 468361      NaN
# 468362      NaN
#
# [468363 rows x 5 columns]
